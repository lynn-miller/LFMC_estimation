# %% [markdown]
# # Extract ERA5 Site Data and Generate Samples
# ## ERA5 Site Data
# For each site in the LFMC sample data, extract the full time series of ERA5 data, gap-fill and save to CSV files. Note: if the output csv files already exist they are assumed to be correct and are not over-written.
#
# ## ERA5 Sample Data
# For each sample, extract the timeseries ERA5 data. The timeseries length is determined by the ERA5_TS_LENGTH value. The sample is rejected if the full timeseries cannot be extracted (start/end outside the full site time series). The extracted ERA5 data is combined to a single dataframe and saved.
#
# ## Input Files
# - `LFMC_sites.csv` and `LFMC_samples.csv` created by the `Extract Auxiliary Data.ipynb` notebook.
#
# ## Output Files
# - The extracted sites data are created in `ERA5_DIR` (by default located in `DATA_DIR/GEE_DIR`). The directory will contain a CSV file for each site.
# - The extracted ERA5 data for all samples are created in ``DATASETS_DIR`. File name include the time series length (i.e. 365days) of the extracted ERA5 data. So, with the default settings is `era5_365days.csv`.
#
# ## Notes
# 1. This notebook should be run after running the `Extract Auxiliary Data.ipynb` notebook.
# 2. The generated name for `GEE_DIR` includes the projection and scale of the extracted GEE data.
# 3. It will take about 10 hours to run if there are no existing site extracts.
# 4. Data for 67724 samples will be extracted. 1051 samples will not be extracted as they were collected before March 2002 (so less than 1 year MODIS data available).
# 5. There will be 4 invalid sites ('C6_340', 'C6_698', 'C6_935', and 'C16_5'), but occasionally extraction from GEE will fail for another site. If this happens re-run the notebook (keep the existing site CSV files so they are not re-extracted).

# %% [markdown]
# ## Initialisation

# %%
import os
os.environ["HDF5_DISABLE_VERSION_CHECK"] = "1"
import numpy as np
import pandas as pd
import re
import time
from datetime import datetime
from datetime import timedelta

import initialise
import common
from data_extract_utils import get_sample_data, extract_timeseries_data, sort_key
from timeseries_extractor import GeeTimeseriesReduceExtractor

# %% [markdown]
# ### Connect to GEE

# %%
import ee
ee.Initialize()

# %% [markdown]
# ### Program parameters and constants
#
# GEE Parameters
# - Weather product is ECMWF/ERA5_LAND/HOURLY - hourly weather data from ERA5
# - Scale/proj set to convert to MODIS resolution/projection
# - Start date is 01/03/2000, to match MODIS data availability

# %%
START_DATE = "2000-03-01"
END_DATE = "2019-01-01"     # Final day retrieved will be 2018-12-31

# ERA5 time series constants
ERA5_TS_LENGTH = 365
ERA5_TS_OFFSET = 1      # ts end this number of days before the sampling date
ERA5_TS_FREQ = 1        # days between consecutive elements in the ts

# ERA5 data details
PRODUCT = "ECMWF/ERA5_LAND/HOURLY"
BANDS = {
    'pre_tot': 'total_precipitation_max',
    'temp_mean': 'temperature_2m_mean',
    'temp_min': 'temperature_2m_min',
    'temp_max': 'temperature_2m_max',
    'dewpt_mean': 'dewpoint_temperature_2m_mean',
    'pet_min': 'potential_evaporation_hourly_min',
    'pet_max': 'potential_evaporation_hourly_max',
}
# Extract data using MODIS scale and projection
SCALE = 463.3127
PROJ = "SR-ORG:6974"

EARLIEST_SAMPLE = datetime.strptime(START_DATE, '%Y-%m-%d') + timedelta(
    days=ERA5_TS_LENGTH * ERA5_TS_FREQ + ERA5_TS_OFFSET - 1)

# %% [markdown]
# ### Directories and Files

# %%
# Directories
GEE_DIR = f"GEE_{common.PROJ.replace(':', '-')}_{int(common.SCALE)}"
ERA5_DIR = os.path.join(common.LFMC_DATA_DIR, GEE_DIR, "ERA5")

# File Names
SITES_INPUT = os.path.join(common.DATASETS_DIR, "LFMC_europe_sites.csv")
SAMPLES_INPUT = os.path.join(common.DATASETS_DIR, "LFMC_europe_samples.csv")
SAMPLES_OUTPUT = os.path.join(common.DATASETS_DIR, f"europe_samples_{ERA5_TS_LENGTH * ERA5_TS_FREQ}days.csv")
ERA5_OUTPUT = os.path.join(common.DATASETS_DIR, f"europe_era5_{ERA5_TS_LENGTH * ERA5_TS_FREQ}days.csv")

# Create output directories if necessary
if not os.path.exists(ERA5_DIR):
    os.makedirs(ERA5_DIR)

# %% [markdown]
# ## Generate the ERA5 sample data
# For each site
# - Get the weather data at MODIS proj/scale
# - Then get the sample data for each sample at the site

# %%
sites = pd.read_csv(SITES_INPUT, float_precision="high")
samples = pd.read_csv(SAMPLES_INPUT, float_precision="high")

# %%
reducers = [ee.Reducer.mean(), ee.Reducer.min(), ee.Reducer.max()]
era5_extractor = GeeTimeseriesReduceExtractor(PRODUCT, BANDS, reducers, START_DATE, END_DATE,
                                              gap_fill=False, dir_name=ERA5_DIR)
era5_extractor.set_proj_scale(PROJ, SCALE)
era5_data, valid_data, invalid_pixels, invalid_sites = extract_timeseries_data(
    era5_extractor, sites, samples, EARLIEST_SAMPLE, ERA5_TS_OFFSET, ERA5_TS_LENGTH, ERA5_TS_FREQ)
# Out:
# Processing site C2_1
# Extracting data for C2_1 (lat: 38.92292 long: -1.71649)
# Processing site C2_2
# Extracting data for C2_2 (lat: 38.30625 long: -2.15313)
# Processing site C2_3
# Extracting data for C2_3 (lat: 38.20625 long: -2.30925)
# Processing site C2_4
# Extracting data for C2_4 (lat: 36.75625 long: -5.43723)
# Processing site C2_5
# Extracting data for C2_5 (lat: 36.76042 long: -5.38552)
# Processing site C2_6
# Extracting data for C2_6 (lat: 42.29375 long: -0.90971)
# Processing site C2_7
# Extracting data for C2_7 (lat: 42.28542 long: -0.89833)
# Processing site C2_8
# Extracting data for C2_8 (lat: 42.27708 long: -1.01647)
# Processing site C2_9
# Extracting data for C2_9 (lat: 42.40208 long: -0.92821)
# Processing site C2_10
# Extracting data for C2_10 (lat: 41.25208 long: -1.2165)
# Processing site C2_11
# Extracting data for C2_11 (lat: 41.19792 long: -1.18227)
# Processing site C2_12
# Extracting data for C2_12 (lat: 41.25625 long: -1.29971)
# Processing site C2_13
# Extracting data for C2_13 (lat: 41.31042 long: -1.43947)
# Processing site C2_14
# Extracting data for C2_14 (lat: 42.24375 long: -0.34052)
# Processing site C2_15
# Extracting data for C2_15 (lat: 42.35208 long: -0.22834)
# Processing site C2_16
# Extracting data for C2_16 (lat: 42.46042 long: -0.35299)
# Processing site C2_17
# Extracting data for C2_17 (lat: 42.43125 long: -0.51654)
# Processing site C2_18
# Extracting data for C2_18 (lat: 40.43958 long: -4.17986)
# Processing site C2_19
# Extracting data for C2_19 (lat: 40.77292 long: -3.71108)
# Processing site C2_20
# Extracting data for C2_20 (lat: 40.44792 long: -4.14205)
# Processing site C2_21
# Extracting data for C2_21 (lat: 40.87708 long: -3.49649)
# Processing site C2_22
# Extracting data for C2_22 (lat: 40.51042 long: -4.15687)
# Processing site C2_23
# Extracting data for C2_23 (lat: 40.60208 long: -3.69061)
# Processing site C2_24
# Extracting data for C2_24 (lat: 40.60208 long: -3.69061)
# Processing site C2_25
# Extracting data for C2_25 (lat: 40.29375 long: -4.31832)
# Processing site C2_26
# Extracting data for C2_26 (lat: 40.68958 long: -4.40981)
# Processing site C2_27
# Extracting data for C2_27 (lat: 40.55625 long: -4.66425)
# Processing site C2_28
# Extracting data for C2_28 (lat: 40.98958 long: -4.00477)
# Processing site C2_29
# Extracting data for C2_29 (lat: 40.66875 long: -4.56224)
# Processing site C2_30
# Extracting data for C2_30 (lat: 38.09375 long: -4.28048)
# Processing site C2_31
# Extracting data for C2_31 (lat: 38.09375 long: -4.28048)
# Processing site C2_32
# Extracting data for C2_32 (lat: 40.89792 long: -2.24629)
# Processing site C2_33
# Extracting data for C2_33 (lat: 40.89375 long: -2.24614)
# Processing site C2_34
# Extracting data for C2_34 (lat: 40.89375 long: -2.24614)
# Processing site C2_35
# Extracting data for C2_35 (lat: 40.86875 long: -2.22326)
# Processing site C2_36
# Extracting data for C2_36 (lat: 40.86875 long: -2.22326)
# Processing site C2_37
# Extracting data for C2_37 (lat: 40.86875 long: -2.22326)
# Processing site C2_38
# Extracting data for C2_38 (lat: 40.82292 long: -2.22172)
# Processing site C2_39
# Extracting data for C2_39 (lat: 40.82708 long: -2.22186)
# Processing site C2_40
# Extracting data for C2_40 (lat: 40.82292 long: -2.22172)
# Processing site C2_41
# Extracting data for C2_41 (lat: 40.83542 long: -2.23315)
# Processing site C2_42
# Extracting data for C2_42 (lat: 40.83542 long: -2.23315)
# Processing site C2_43
# Extracting data for C2_43 (lat: 40.83542 long: -2.23315)
# Processing site C2_44
# Extracting data for C2_44 (lat: 40.50625 long: -3.00032)
# Processing site C2_45
# Extracting data for C2_45 (lat: 41.04375 long: -3.207)
# Processing site C2_46
# Extracting data for C2_46 (lat: 41.04375 long: -3.207)
# Processing site C2_47
# Extracting data for C2_47 (lat: 37.00625 long: -6.46729)
# Processing site C2_48
# Extracting data for C2_48 (lat: 37.01042 long: -6.46764)
# Processing site C2_49
# Extracting data for C2_49 (lat: 37.03125 long: -6.54249)
# Processing site C2_50
# Extracting data for C2_50 (lat: 37.73125 long: -3.5008)
# Processing site C2_51
# Extracting data for C2_51 (lat: 37.75208 long: -3.50179)
# Processing site C2_52
# Extracting data for C2_52 (lat: 43.50208 long: -7.51649)
# Processing site C2_53
# Extracting data for C2_53 (lat: 43.19792 long: -7.47892)
# Processing site C2_54
# Extracting data for C2_54 (lat: 42.60625 long: -7.18105)
# Processing site C2_55
# Extracting data for C2_55 (lat: 42.73542 long: -7.16195)
# Processing site C2_56
# Extracting data for C2_56 (lat: 42.70208 long: -7.1581)
# Processing site C2_57
# Extracting data for C2_57 (lat: 42.64792 long: -7.22551)
# Processing site C2_58
# Extracting data for C2_58 (lat: 43.33958 long: -7.59374)
# Processing site C2_59
# Extracting data for C2_59 (lat: 43.39792 long: -7.5609)
# Processing site C2_60
# Extracting data for C2_60 (lat: 43.42708 long: -7.54733)
# Processing site C2_61
# Extracting data for C2_61 (lat: 43.41042 long: -7.63129)
# Processing site C2_62
# Extracting data for C2_62 (lat: 43.44375 long: -7.64123)
# Processing site C2_63
# Extracting data for C2_63 (lat: 38.25625 long: -1.78022)
# Processing site C2_64
# Extracting data for C2_64 (lat: 37.96458 long: -5.61005)
# Processing site C2_65
# Extracting data for C2_65 (lat: 39.30625 long: -4.32137)
# Processing site C2_66
# Extracting data for C2_66 (lat: 39.31875 long: -4.37061)
# Processing site C2_67
# Extracting data for C2_67 (lat: 39.33542 long: -4.42553)
# Processing site C2_68
# Extracting data for C2_68 (lat: 39.33958 long: -4.44734)
# Processing site C2_69
# Extracting data for C2_69 (lat: 39.34792 long: -4.4802)
# Processing site C2_70
# Extracting data for C2_70 (lat: 39.33958 long: -4.50121)
# Processing site C2_71
# Extracting data for C2_71 (lat: 39.05208 long: -0.95237)
# Processing site C2_72
# Extracting data for C2_72 (lat: 39.12292 long: -0.96407)
# Processing site C2_73
# Extracting data for C2_73 (lat: 39.11875 long: -0.9479)
# Processing site C2_74
# Extracting data for C2_74 (lat: 39.09375 long: -0.91535)
# Processing site C8_1
# Extracting data for C8_1 (lat: 39.93958 long: -5.77404)
# Processing site C9_3
# Extracting data for C9_3 (lat: 43.53958 long: 6.90039)
# Processing site C9_4
# Extracting data for C9_4 (lat: 44.48542 long: 6.15864)
# Processing site C9_6
# Extracting data for C9_6 (lat: 44.44792 long: 4.46207)
# Processing site C9_7
# Extracting data for C9_7 (lat: 42.44375 long: 8.85065)
# Processing site C9_8
# Extracting data for C9_8 (lat: 44.43125 long: 3.94733)
# Processing site C9_9
# Extracting data for C9_9 (lat: 42.91042 long: 2.7961)
# Processing site C9_10
# Extracting data for C9_10 (lat: 41.72292 long: 9.33683)
# Processing site C9_11
# Extracting data for C9_11 (lat: 41.73542 long: 9.00921)
# Processing site C9_15
# Extracting data for C9_15 (lat: 43.42292 long: 5.99787)
# Processing site C9_16
# Extracting data for C9_16 (lat: 43.69375 long: 5.06828)
# Processing site C9_17
# Extracting data for C9_17 (lat: 43.71042 long: 5.06393)
# Processing site C9_18
# Extracting data for C9_18 (lat: 42.60208 long: 9.42219)
# Processing site C9_19
# Extracting data for C9_19 (lat: 43.21875 long: 6.36654)
# Processing site C9_20
# Extracting data for C9_20 (lat: 43.21875 long: 6.37226)
# Processing site C9_21
# Extracting data for C9_21 (lat: 43.61458 long: 3.20271)
# Processing site C9_22
# Extracting data for C9_22 (lat: 44.34375 long: 4.10456)
# Processing site C9_23
# Extracting data for C9_23 (lat: 43.23958 long: 5.80248)
# Processing site C9_24
# Extracting data for C9_24 (lat: 43.12708 long: 2.92016)
# Processing site C9_25
# Extracting data for C9_25 (lat: 43.47708 long: 6.48557)
# Processing site C9_26
# Extracting data for C9_26 (lat: 42.51458 long: 2.87442)
# Processing site C9_27
# Extracting data for C9_27 (lat: 43.57708 long: 3.71835)
# Processing site C9_28
# Extracting data for C9_28 (lat: 43.35208 long: 5.16572)
# No data found for C9_28
# Processing site C9_29
# Extracting data for C9_29 (lat: 43.88542 long: 4.4255)
# Processing site C9_30
# Extracting data for C9_30 (lat: 42.64375 long: 2.4782)
# Processing site C9_31
# Extracting data for C9_31 (lat: 41.65208 long: 9.32656)
# Processing site C9_32
# Extracting data for C9_32 (lat: 44.03125 long: 5.92)
# Processing site C9_33
# Extracting data for C9_33 (lat: 43.61875 long: 6.944)
# Processing site C9_34
# Extracting data for C9_34 (lat: 43.98125 long: 6.49986)
# Processing site C9_35
# Extracting data for C9_35 (lat: 43.83542 long: 7.34463)
# Processing site C9_36
# Extracting data for C9_36 (lat: 43.90208 long: 5.14381)
# Processing site C9_37
# Extracting data for C9_37 (lat: 43.73958 long: 5.62003)
# Processing site C9_38
# Extracting data for C9_38 (lat: 43.74375 long: 3.59603)
# Processing site C9_39
# Extracting data for C9_39 (lat: 42.33958 long: 9.17983)
# Processing site C9_40
# Extracting data for C9_40 (lat: 44.22708 long: 4.02083)
# Processing site C9_41
# Extracting data for C9_41 (lat: 44.27708 long: 5.22309)
# Processing site C9_42
# Extracting data for C9_42 (lat: 41.92708 long: 8.70581)
# No data found for C9_42
# Processing site C12_1
# Extracting data for C12_1 (lat: 40.60208 long: 8.15226)
# No data found for C12_1
# Processing site C15_1
# Extracting data for C15_1 (lat: 41.34375 long: 1.05726)

# %% [markdown]
# Summary of sites/samples not extracted

# %%
print(f'Invalid sites: {len(invalid_sites)}; Invalid pixels: {len(invalid_pixels)}')
print(invalid_sites)
print(invalid_pixels)
# Out:
# Invalid sites: 3; Invalid pixels: 0
# ['C9_28', 'C9_42', 'C12_1']
# []

# %% [markdown]
# ## Save and display sample weather data

# %%
era5_data = pd.DataFrame(era5_data)
ts_days = (ERA5_TS_LENGTH - 1) * ERA5_TS_FREQ
era5_data.columns = ["ID"] + [f'{day-ERA5_TS_OFFSET:04}_{band+1}'
                               for day in range(-ts_days, 1, ERA5_TS_FREQ)
                               for band in range(len(BANDS))]
era5_data.sort_values('ID', inplace=True, key=lambda x: x.apply(sort_key))
era5_data
# Out:
#             ID        -365_1      -365_2      -365_3      -365_4      -365_5  \
# 0       C2_1_1  4.994869e-06  279.343393  272.426605  286.665955  266.562732
# 1       C2_1_3  4.700086e-05  300.064088  293.295334  305.981644  278.305990
# 2       C2_2_1  0.000000e+00  281.677337  274.818909  288.502975  270.162066
# 3      C2_2_10  1.722574e-06  299.227581  290.983368  305.792938  278.115561
# 4       C2_3_1  0.000000e+00  279.570078  272.320862  286.348679  269.395220
# ...        ...           ...         ...         ...         ...         ...
# 8393  C15_1_13  5.412996e-05  294.831380  288.597534  302.681396  285.030111
# 8394  C15_1_19  2.782345e-05  298.152774  292.087646  305.539581  288.400694
# 8395  C15_1_25  2.311292e-03  297.696341  291.804367  305.228455  286.585228
# 8396  C15_1_31  8.583069e-07  300.132219  294.407043  307.781067  288.305840
# 8397  C15_1_37  8.075988e-03  290.701637  287.996658  294.799881  288.069643
#
#         -365_6        -365_7        -364_1      -364_2  ...      -002_5  \
# 0    -0.000982 -1.172237e-04  0.000000e+00  282.091725  ...  275.727264
# 1    -0.001138 -1.177415e-04  4.699528e-05  299.458803  ...  284.632844
# 2    -0.000892 -7.554889e-06  1.297291e-06  281.923733  ...  276.670230
# 3    -0.001068 -4.016422e-05  1.710653e-06  298.724834  ...  281.555777
# 4    -0.000818 -6.139278e-06  1.297291e-06  280.326321  ...  276.276025
# ...        ...           ...           ...         ...  ...         ...
# 8393 -0.001073 -2.433546e-06  0.000000e+00  295.770727  ...  290.111422
# 8394 -0.001074 -1.419336e-06  1.761168e-04  297.875079  ...  285.737535
# 8395 -0.001150 -9.424984e-07  2.746779e-03  295.381376  ...  291.939104
# 8396 -0.001104 -2.764165e-06  8.523463e-07  298.516801  ...  282.525814
# 8397 -0.000535  2.592802e-06  1.964137e-03  291.025821  ...  288.646969
#
#         -002_6        -002_7    -001_1      -001_2      -001_3      -001_4  \
# 0    -0.000940  1.974404e-07  0.000002  288.199837  280.332153  295.517288
# 1    -0.001179 -3.071502e-06  0.000166  299.828926  291.924576  307.572403
# 2    -0.000796  5.029142e-07  0.000039  287.716304  280.806351  295.198883
# 3    -0.001087 -1.929700e-05  0.000095  299.176420  290.457779  306.713028
# 4    -0.000768  8.456409e-07  0.000139  285.884516  279.189163  292.888336
# ...        ...           ...       ...         ...         ...         ...
# 8393 -0.001096 -4.036352e-06  0.001074  298.003263  292.430466  302.726273
# 8394 -0.001460 -1.625158e-06  0.000059  295.294369  289.159363  301.848465
# 8395 -0.000916 -1.621619e-05  0.001561  297.682663  293.108673  303.832428
# 8396 -0.001012 -2.685934e-06  0.008602  293.761960  291.439362  297.265640
# 8397 -0.000783  1.406670e-05  0.003172  292.946888  289.439819  299.083710
#
#           -001_5    -001_6        -001_7
# 0     274.865705 -0.000963 -3.344938e-05
# 1     284.558547 -0.001129 -1.158565e-05
# 2     277.632065 -0.000785  5.029142e-07
# 3     285.018345 -0.001055 -3.539026e-07
# 4     276.765692 -0.000767  1.762062e-06
# ...          ...       ...           ...
# 8393  286.349009 -0.001196 -5.979091e-06
# 8394  281.938951 -0.001150 -1.290627e-04
# 8395  285.431698 -0.001314 -3.438257e-05
# 8396  290.789291 -0.000722  1.836568e-06
# 8397  288.311169 -0.000736  2.503395e-06
#
# [8398 rows x 2556 columns]

# %%
era5_data.to_csv(ERA5_OUTPUT, index=False, float_format='%.4g')

# %% [markdown]
# Save and display the valid samples

# %%
valid_samples = samples[valid_data].sort_values('ID', key=lambda x: x.apply(sort_key))
valid_samples.to_csv(SAMPLES_OUTPUT, index=False)
valid_samples
# Out:
#            ID  Latitude  Longitude Sampling date  Sampling year  \
# 317    C2_1_1  38.92292   -1.71649    2006-04-10           2006
# 318    C2_1_3  38.92292   -1.71649    2006-07-25           2006
# 501    C2_2_1  38.30625   -2.15313    2006-04-11           2006
# 502   C2_2_10  38.30625   -2.15313    2006-07-25           2006
# 513    C2_3_1  38.20625   -2.30925    2006-04-11           2006
# ..        ...       ...        ...           ...            ...
# 109  C15_1_13  41.34375    1.05726    2017-06-27           2017
# 110  C15_1_19  41.34375    1.05726    2017-07-26           2017
# 111  C15_1_25  41.34375    1.05726    2017-08-09           2017
# 112  C15_1_31  41.34375    1.05726    2017-09-05           2017
# 113  C15_1_37  41.34375    1.05726    2017-09-26           2017
#
#                                             Land Cover  LFMC value   Site  \
# 317  Mosaic natural vegetation (tree, shrub, herbac...    74.33500   C2_1
# 318  Mosaic natural vegetation (tree, shrub, herbac...    87.42500   C2_1
# 501  Tree cover, needleleaved, evergreen, closed to...    86.10800   C2_2
# 502  Tree cover, needleleaved, evergreen, closed to...    60.51667   C2_2
# 513  Mosaic tree and shrub (>50%) / herbaceous cove...   110.14500   C2_3
# ..                                                 ...         ...    ...
# 109  Tree cover, broadleaved, deciduous, closed to ...   106.92565  C15_1
# 110  Tree cover, broadleaved, deciduous, closed to ...    84.77083  C15_1
# 111  Tree cover, broadleaved, deciduous, closed to ...    79.33530  C15_1
# 112  Tree cover, broadleaved, deciduous, closed to ...    69.21358  C15_1
# 113  Tree cover, broadleaved, deciduous, closed to ...    78.95666  C15_1
#
#     Czone1 Czone2 Czone3  Day_sin  Day_cos  Long_sin  Long_cos  Lat_norm  \
# 317      B     BS    BSk -0.99111  0.13301  -0.02995   0.99955   0.71624
# 318      B     BS    BSk  0.37771  0.92592  -0.02995   0.99955   0.71624
# 501      B     BS    BSk -0.98868  0.15006  -0.03757   0.99929   0.71281
# 502      B     BS    BSk  0.37771  0.92592  -0.03757   0.99929   0.71281
# 513      B     BS    BSk -0.98868  0.15006  -0.04029   0.99919   0.71226
# ..     ...    ...    ...      ...      ...       ...       ...       ...
# 109      C     Cs    Csb -0.09454  0.99552   0.01845   0.99983   0.72969
# 110      C     Cs    Csb  0.39359  0.91929   0.01845   0.99983   0.72969
# 111      C     Cs    Csb  0.60162  0.79878   0.01845   0.99983   0.72969
# 112      C     Cs    Csb  0.89584  0.44438   0.01845   0.99983   0.72969
# 113      C     Cs    Csb  0.99511  0.09882   0.01845   0.99983   0.72969
#
#      Elevation    Slope  Aspect_sin  Aspect_cos
# 317    0.15258  0.16544     0.94004     0.34108
# 318    0.15258  0.16544     0.94004     0.34108
# 501    0.16236  0.15632     0.22862     0.97352
# 502    0.16236  0.15632     0.22862     0.97352
# 513    0.19286  0.06576    -0.99408     0.10867
# ..         ...      ...         ...         ...
# 109    0.12533  0.20084    -0.57996     0.81464
# 110    0.12533  0.20084    -0.57996     0.81464
# 111    0.12533  0.20084    -0.57996     0.81464
# 112    0.12533  0.20084    -0.57996     0.81464
# 113    0.12533  0.20084    -0.57996     0.81464
#
# [8398 rows x 20 columns]
