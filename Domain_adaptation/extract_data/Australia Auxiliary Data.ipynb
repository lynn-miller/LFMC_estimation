# %% [markdown]
# # Process Globe-LFMC samples and extract DEM Data
# Extracts the samples for locations in the CONUS from the Globe-LFMC spread sheet and adds the normalised DEM, climate zone, and other auxiliary data. DEM data is from the GEE SRTM DEM product, extracted using the MODIS projection and scale. Sites within the same MODIS pixel are merged. The following files are created:
# - `LFMC_CONUS.csv`: CONUS data extracted from the Globe-LFMC dataset
# - `LFMC_sites.csv`: sites extracted from the Globe-LFMC CONUS data and augmented with normalised DEM and location data
# - `LFMC_samples.csv`: Globe-LFMC CONUS sample data augmented with auxiliary variables
#
# ### Notes
# 1. The `Globe-LFMC-v2.xlsx` should exist in the `INPUT_DIR` directory - by default, a sub-directory of `DATA_DIR`
# 2. The tiff containing the Koppen climate zone data (`Beck_KG_V1_present_0p0083.tif` available from https://figshare.com/articles/dataset/Present_and_future_K_ppen-Geiger_climate_classification_maps_at_1-km_resolution/6396959/2) should also be in `INPUT_DIR`, as should either the `legend.txt` file (available from the same site) or `Climate_zones.csv`. If `Climate_zones.csv` doesn't exist, it needs to be created from `legend.txt` by uncommenting and running the first code cell under "Climate zone processing".
# 3. `EXTRACT_NAME` is a sub-directory of `DATA_DIR`. It will be created if it doesn't exist. All data files created by this and other data extraction notebooks will be located in sub-directories of this directory.
# 4. `LFMC_CONUS.csv` is created in the `INPUT_DIR` directory.
# 5. All other created files are CSVs and stored in the `SAMPLE_DIR` directory, by default a sub-directory of `DATA_DIR/EXTRACT_NAME`.
# 6. The samples data output by this code is further processed by the MODIS extraction code to remove the snow samples.

# %%
import os
import numpy as np
import pandas as pd
import time
from datetime import datetime
from datetime import timedelta

import initialise
import common
from data_extract_utils import normalise_dem
from data_extract_utils import extract_koppen_data
from data_prep_utils import normalise

# %% [markdown]
# Define input and output files

# %%
# Globe-LFMC file and sheet name
GLOBE_LFMC = os.path.join(common.SOURCE_DIR, "Globe-LFMC-v2.xlsx")
SHEET_NAME = "LFMC data"
# GLOBE_LFMC = os.path.join(common.SOURCE_DIR, "Globe-LFMC.csv")

# File Names
LFMC_RAW = os.path.join(common.SOURCE_DIR, "LFMC_Australia.csv")               # CSV of Australian data extracted from the Globe-LFMC dataset
KOPPEN_TIF = os.path.join(common.SOURCE_DIR, 'Beck_KG_V1_present_0p0083.tif')  # Tiff of Koppen climate zone values
LEGEND_FILE = os.path.join(common.SOURCE_DIR, 'legend.txt')                    # Text file with Koppen climate zone legend
KOPPEN_LEGEND = os.path.join(common.SOURCE_DIR, 'Climate_zones.csv')           # CSV of Koppen climate zone legend

SITES_OUTPUT = os.path.join(common.DATASETS_DIR, 'LFMC_australia_sites.csv')
SAMPLES_OUTPUT = os.path.join(common.DATASETS_DIR, 'LFMC_australia_samples.csv')

if not os.path.exists(common.DATASETS_DIR):
    os.makedirs(common.DATASETS_DIR)

# %% [markdown]
# Other constants/parameters

# %%
# DEM Product, projection and resolution
DEM_PRODUCT = 'USGS/SRTMGL1_003'
DEM_PROJ = "EPSG:4326"
DEM_SCALE = 30

# Floating point precision
FLOAT_PRE = 5

# %% [markdown]
# Initialise Google Earth Engine

# %%
import ee
ee.Initialize()

# %% [markdown]
# ## Point-based Processing
# Extracts the DEM data from GEE usong the native DEM projection and resolution. Keeps the sample site latitude and longitude, and adds the elevation/slope/aspect.
# - Parameter:
#  - sites: Dataframe of sample sites
# - Returns: Dataframe of sites, latitude and longitude and the added elevation/slope/aspect attributes

# %%
def sites_by_point(sites):
    dem_image = ee.Terrain.products(ee.Image(DEM_PRODUCT))
    points = [ee.Geometry.Point(site.Longitude, site.Latitude) for x, site in sites.iterrows()]
    dem_col = ee.ImageCollection(dem_image)
    col_list = [dem_col.getRegion(point, DEM_SCALE, DEM_PROJ) for point in points]
    dem_list = ee.List(col_list).getInfo()
    dem_data = pd.DataFrame([item[1] for item in dem_list], columns=dem_list[0][0])
    dem_data.id = sites.Site
    dem_data.rename(columns={"id": "Site"}, inplace=True)
    dem_df = sites.merge(dem_data[['Site', 'elevation', 'slope', 'aspect']])
    dem_df.columns = ['Site', 'Latitude', 'Longitude', 'Elevation', 'Slope', 'Aspect']
    return dem_df

# %% [markdown]
# ## Pixel-based Processing
# Extracts the DEM data at the requested projection and resolution. Terrain.products adds the slope and aspect. A reducer is used so terrain product info is added before resampling.
# - Parameters:
#  - sites: dataframe of sampling sites
#  - scale/proj: the required scale/proj (e.g. MODIS scale/proj - or map scale/proj)
#  - maxPixels: Reducer parameter specifying the maximum number of DEM pixels to use to compute each down-sampled pixel. Doesn't need to be exact but make sure it's large enough - 512 is good for MODIS
# - Returns: Dataframe of sites with latitude and longitude set to the pixel centroid as returned by GEE and the added elevation/slope/aspect attributes

# %%
def sites_by_pixel(sites, scale, proj, maxPixels):
    dem_image = ee.Terrain.products(ee.Image(DEM_PRODUCT)).reduceResolution(ee.Reducer.mean(), maxPixels=maxPixels)
    points = [ee.Geometry.Point(site.Longitude, site.Latitude) for x, site in sites.iterrows()]
    dem_col = ee.ImageCollection(dem_image)
    col_list = [dem_col.getRegion(point, scale, proj) for point in points]
    dem_list = ee.List(col_list).getInfo()
    dem_data = pd.DataFrame([item[1] for item in dem_list], columns=dem_list[0][0])
    dem_data.id = sites.Site
    dem_data.columns = ['Site', 'Longitude', 'Latitude', 'time', 'Elevation', 'Slope', 'Aspect', 'hillshade']
    dem_df = dem_data.drop(columns=["time", "hillshade"])
    return dem_df

# %% [markdown]
# ## Main Processing
# - If the LFMC_RAW file already exists, load it.
# - Otherwise extract Globe LFMC data from the excel workbook sheet and save to the LFMC_RAW file.

# %%
if os.path.exists(LFMC_RAW):
    LFMC_data = pd.read_csv(LFMC_RAW, index_col=0, float_precision="high", parse_dates=["Sampling date"],
                           dtype={8: str, 10: np.int32, 11: np.int16, 14: np.int16, 23: str})
else:    
    LFMC_data = pd.read_excel(GLOBE_LFMC, SHEET_NAME).dropna(how="all")
    # LFMC_data = pd.read_csv(GLOBE_LFMC).dropna(how="all")
    LFMC_data = LFMC_data[(LFMC_data.Country.isin(['Australia']))
                          & (LFMC_data["Sampling date"] >= common.START_DATE)]
    LFMC_data.to_csv(LFMC_RAW)
    LFMC_data = LFMC_data.astype(dtype={'Sampling year': np.int32, 'Protocol': np.int16, 'Units': np.int16})
LFMC_data
# Out:
#               ID  Contact     Sitename                  State/Region  \
# 159972   C10_1_1  Newnham       Ballan                      Victoria
# 159973   C10_1_2  Newnham       Ballan                      Victoria
# 159974   C10_1_3  Newnham       Ballan                      Victoria
# 159975   C10_1_4  Newnham       Ballan                      Victoria
# 159976   C10_2_1  Newnham  Braidwood-A               New South Wales
# ...          ...      ...          ...                           ...
# 161712  C18_3_32    Yebra    Namadgi-2  Australian Capital Territory
# 161713  C18_3_33    Yebra    Namadgi-2  Australian Capital Territory
# 161714  C18_3_34    Yebra    Namadgi-2  Australian Capital Territory
# 161715  C18_3_35    Yebra    Namadgi-2  Australian Capital Territory
# 161716  C18_3_36    Yebra    Namadgi-2  Australian Capital Territory
#
#           Country   Latitude   Longitude Sampling time Sampling date  \
# 159972  Australia -37.635167  144.221317           NaN    2008-10-20
# 159973  Australia -37.635167  144.221317           NaN    2008-11-10
# 159974  Australia -37.635167  144.221317           NaN    2008-12-01
# 159975  Australia -37.635167  144.221317           NaN    2009-01-19
# 159976  Australia -35.406367  149.803217           NaN    2006-01-05
# ...           ...        ...         ...           ...           ...
# 161712  Australia -35.607070  148.865740           NaN    2016-09-02
# 161713  Australia -35.607070  148.865740           NaN    2016-09-02
# 161714  Australia -35.607070  148.865740           NaN    2016-11-01
# 161715  Australia -35.607070  148.865740           NaN    2016-11-01
# 161716  Australia -35.607070  148.865740           NaN    2016-11-01
#
#         Sampling year  ...  Units NDVI SD min  NDVI SD max  NDVI CV min  \
# 159972           2008  ...      1    0.032105     0.123081     0.087244
# 159973           2008  ...      1    0.032105     0.123081     0.087244
# 159974           2008  ...      1    0.032105     0.123081     0.087244
# 159975           2009  ...      1    0.032105     0.123081     0.087244
# 159976           2006  ...      1    0.033170     0.105659     0.065878
# ...               ...  ...    ...         ...          ...          ...
# 161712           2016  ...      1    0.033528     0.081472     0.047433
# 161713           2016  ...      1    0.033528     0.081472     0.047433
# 161714           2016  ...      1    0.033528     0.081472     0.047433
# 161715           2016  ...      1    0.033528     0.081472     0.047433
# 161716           2016  ...      1    0.033528     0.081472     0.047433
#
#         NDVI CV max                                  Species collected  \
# 159972     0.196893                  Lolium multiflorum, Trifolium sp.
# 159973     0.196893                  Lolium multiflorum, Trifolium sp.
# 159974     0.196893                  Lolium multiflorum, Trifolium sp.
# 159975     0.196893                  Lolium multiflorum, Trifolium sp.
# 159976     0.164409                                      Unknown grass
# ...             ...                                                ...
# 161712     0.125154  Leptospermum myrtifolium, Oxylobium ellipticum...
# 161713     0.125154  Eucalyptus dalrympleana, Eucalyptus pauciflora...
# 161714     0.125154               Poa labillardierei, Themeda triandra
# 161715     0.125154  Leptospermum myrtifolium, Oxylobium ellipticum...
# 161716     0.125154  Eucalyptus dalrympleana, Eucalyptus pauciflora...
#
#         Elevation(m.a.s.l)  Slope(%)  \
# 159972                 NaN       NaN
# 159973                 NaN       NaN
# 159974                 NaN       NaN
# 159975                 NaN       NaN
# 159976                 NaN       NaN
# ...                    ...       ...
# 161712              1000.0       NaN
# 161713              1000.0       NaN
# 161714              1000.0       NaN
# 161715              1000.0       NaN
# 161716              1000.0       NaN
#
#                                                 Reference  \
# 159972  Newnham, G.J., Verbesselt, J., Grant, I.F., An...
# 159973  Newnham, G.J., Verbesselt, J., Grant, I.F., An...
# 159974  Newnham, G.J., Verbesselt, J., Grant, I.F., An...
# 159975  Newnham, G.J., Verbesselt, J., Grant, I.F., An...
# 159976  Newnham, G.J., Verbesselt, J., Grant, I.F., An...
# ...                                                   ...
# 161712  Yebra, M., Quan, X.W., Riano, D., Rozas Larrao...
# 161713  Yebra, M., Quan, X.W., Riano, D., Rozas Larrao...
# 161714  Yebra, M., Quan, X.W., Riano, D., Rozas Larrao...
# 161715  Yebra, M., Quan, X.W., Riano, D., Rozas Larrao...
# 161716  Yebra, M., Quan, X.W., Riano, D., Rozas Larrao...
#
#         Name of picture file
# 159972                   NaN
# 159973                   NaN
# 159974                   NaN
# 159975                   NaN
# 159976                   NaN
# ...                      ...
# 161712                   NaN
# 161713                   NaN
# 161714                   NaN
# 161715                   NaN
# 161716                   NaN
#
# [673 rows x 23 columns]

# %% [markdown]
# ### Site processing
# Extract the unique sites from the Globe-LFMC data

# %%
LFMC_data["Site"] = LFMC_data.ID.str.rsplit("_", 1, expand=True)[0]
sites = LFMC_data[["Site", "Latitude", "Longitude"]].drop_duplicates().reset_index(drop=True)
sites
# Out:
#       Site   Latitude   Longitude
# 0    C10_1 -37.635167  144.221317
# 1    C10_2 -35.406367  149.803217
# 2    C10_3 -35.420000  149.793167
# 3    C10_4 -38.225677  145.563300
# 4    C10_5 -33.680889  117.610167
# 5    C10_6 -35.367667  149.053500
# 6    C10_7 -42.848333  147.489500
# 7    C10_8 -38.089457  145.430665
# 8    C10_9 -26.162889  121.558778
# 9   C10_10 -35.277750  149.196583
# 10  C10_11 -35.268500  150.408667
# 11  C10_12 -35.304500  149.170000
# 12  C10_13 -17.029667  125.115944
# 13  C10_14 -35.241380  141.224670
# 14  C10_15 -35.240500  141.215180
# 15  C10_16 -15.586560  128.233800
# 16  C10_17 -17.062889  125.260917
# 17  C10_18 -17.130861  125.373861
# 18  C10_19 -34.216972  116.383111
# 19  C10_20 -35.419139  148.950556
# 20  C10_21 -35.206500  149.026667
# 21   C11_1 -35.646811  148.148314
# 22   C11_2 -33.657838  150.616076
# 23   C11_3 -33.660198  150.617703
# 24   C11_4 -33.610700  150.638400
# 25   C11_5 -36.130200  146.611900
# 26   C11_6 -36.270400  146.653100
# 27   C11_7 -33.615278  150.723611
# 28   C11_8 -37.651600  148.816700
# 29   C11_9 -37.567900  149.108800
# 30  C11_10 -37.605000  148.905600
# 31  C11_11 -37.476600  145.233400
# 32  C11_12 -33.689450  150.234200
# 33  C11_13 -36.138700  147.332200
# 34  C11_14 -34.066156  150.472319
# 35  C11_15 -33.130210  150.699490
# 36  C11_16 -35.656611  148.151667
# 37  C11_17  150.387894 -33.743749   841.387358   9.156110  133.778702
# 38  C11_18  144.094056 -37.422915   711.779526   2.912918  185.781464
# 39   C18_1  149.051833 -35.277082   582.627433   4.324331  172.668520
# 40   C18_2  148.816850 -35.597915  1043.699627  14.536263  141.000588
# 41   C18_3  148.863097 -35.606249  1267.720593  15.147289   81.541654

# %% [markdown]
# Normalise the DEM data and save the sites data. Note: sites with same latitude/longitude are *not* merged yet

# %%
dem_norm = normalise_dem(dem_df.set_index('Site'), input_columns=['Longitude', 'Latitude', 'Elevation', 'Slope', 'Aspect'], precision=FLOAT_PRE)
dem_norm = dem_norm.reset_index()
dem_norm
# Out:
#       Site  Longitude  Latitude  Elevation    Slope     Aspect  Long_sin  \
# 0    C10_1  144.22103 -37.63542    0.08333  0.02654  146.93471   0.58466
# 1    C10_2  149.80151 -35.40625    0.11424  0.02920  126.44411   0.50300
# 2    C10_3  149.78896 -35.41875    0.11300  0.03356  188.61237   0.50319
# 3    C10_4  145.56676 -38.22708    0.00201  0.02290  147.48467   0.56545
# 4    C10_5  117.61153 -33.68125    0.05221  0.03066  130.75828   0.88611
# 5    C10_6  149.05740 -35.36875    0.10626  0.04661  179.44227   0.51418
# 6    C10_7  147.48628 -42.84792    0.00094  0.02082  118.09644   0.53750
# 7    C10_8  145.43017 -38.08958    0.00367  0.01428  128.28047   0.56741
# 8    C10_9  121.56263 -26.16458    0.08432  0.01821  154.30854   0.85207
# 9   C10_10  149.19474 -35.27708    0.09635  0.02366  177.00924   0.51212
# 10  C10_11  150.40931 -35.26875    0.01079  0.08912  148.82362   0.49380
# 11  C10_12  149.17192 -35.30625    0.09371  0.03917  155.36155   0.51246
# 12  C10_13  125.11829 -17.03125    0.04236  0.02382  188.43156   0.81797
# 13  C10_14  141.22344 -35.23958    0.01094  0.02607  172.09985   0.62628
# 14  C10_15  141.21323 -35.23958    0.00924  0.02320  145.96739   0.62642
# 15  C10_16  128.23378 -15.58542    0.00145  0.01813  138.21606   0.78549
# 16  C10_17  125.26265 -17.06458    0.05069  0.01841  159.61150   0.81651
# 17  C10_18  125.37289 -17.13125    0.05947  0.02566  208.14035   0.81540
# 18  C10_19  116.38647 -34.21875    0.03587  0.05321  154.49882   0.89582
# 19  C10_20  148.95045 -35.41875    0.10795  0.04367   96.52165   0.51578
# 20  C10_21  149.02369 -35.20625    0.09647  0.03897  107.04008   0.51468
# 21   C11_1  148.15107 -35.64792    0.20652  0.08226  177.54375   0.52768
# 22   C11_2  150.61524 -33.65625    0.04450  0.11601  124.23253   0.49067
# 23   C11_3  150.61753 -33.66042    0.04410  0.12418  154.87683   0.49064
# 24   C11_4  150.64018 -33.61042    0.02685  0.12543  128.35463   0.49029
# 25   C11_5  146.61286 -36.13125    0.04390  0.06139  164.37065   0.55029
# 26   C11_6  146.64838 -36.26875    0.07551  0.11418  175.01342   0.54978
# 27   C11_7  150.72251 -33.61458    0.00586  0.03201  157.08818   0.48904
# 28   C11_8  148.81615 -37.65208    0.02754  0.09391  184.82496   0.51779
# 37  -0.86939   0.31253    -0.72202     0.69187
# 38  -0.80998   0.29209     0.10073     0.99491
# 39  -0.85763   0.30402    -0.12761     0.99182
# 40  -0.85552   0.30223    -0.62931     0.77715
# 41  -0.85593   0.30219    -0.98912    -0.14709

# %% [markdown]
# ### Date processing
# Create dataframe with dates and normalised day-of-year

# %%
days = pd.date_range(common.START_DATE, common.END_DATE, inclusive="left")
doy = pd.Series(normalise(days.dayofyear, method='range', data_range=(1, 366), scaled_range=(-np.pi, np.pi)))
days_df = pd.DataFrame({"Date": days, 
                        "Day_sin": doy.transform(np.sin).round(FLOAT_PRE),
                        "Day_cos": doy.transform(np.cos).round(FLOAT_PRE)})
days_df
# Out:
#            Date  Day_sin  Day_cos
# 0    2000-03-01 -0.85876 -0.51237
# 1    2000-03-02 -0.86746 -0.49751
# 2    2000-03-03 -0.87589 -0.48251
# 3    2000-03-04 -0.88407 -0.46736
# 4    2000-03-05 -0.89198 -0.45207
# ...         ...      ...      ...
# 6875 2018-12-27  0.08596 -0.99630
# 6876 2018-12-28  0.06880 -0.99763
# 6877 2018-12-29  0.05162 -0.99867
# 6878 2018-12-30  0.03442 -0.99941
# 6879 2018-12-31  0.01721 -0.99985
#
# [6880 rows x 3 columns]

# %% [markdown]
# ### Climate zone processing

# %% [markdown]
# #### Create the Koppen legend csv file
# If the `KOPPEN_LEGEND` file doesn't exist, uncomment and run the following cell. This will create it from the `legend.txt` file that can be downloaded with the climate zones tiff.

# %%
# legend = {}
# count = 0
# with open(LEGEND_FILE) as fp:
#     for ln in fp:
#         line = ln.split(':')
#         number = line[0].strip()
#         if number.isnumeric():
#             count += 1
#             key = int(line[0].strip())
#             parts = line[1].split('[')
#             colour = parts[1].strip().strip(']').split(' ')
#             code = parts[0].strip()[:3]
#             descr = parts[0].strip()[5:]
#             value = {'Number': number, 'Code': code, 'Description': descr, 'Red': colour[0], 'Green': colour[1], 'Blue': colour[2]}
#             legend[key] = value
# legend_df = pd.DataFrame.from_dict(legend, orient='index')
# legend_df.to_csv(KOPPEN_LEGEND, index=False)

# %% [markdown]
# #### Extract climate zones for sites
# Extract the climate zone for each site and add to the sites data.

# %%
cz_columns = ['Czone1', 'Czone2', 'Czone3']
extract_koppen_data(KOPPEN_TIF, KOPPEN_LEGEND, sites, loc_columns=['Longitude', 'Latitude'], cz_columns=cz_columns)
dem_norm = dem_norm.merge(sites[['Site', 'Czone1', 'Czone2', 'Czone3']], on='Site')
dem_norm.to_csv(SITES_OUTPUT, index=False)
dem_norm
# Out:
#       Site  Longitude  Latitude  Elevation    Slope     Aspect  Long_sin  \
# 0    C10_1  144.22103 -37.63542    0.08333  0.02654  146.93471   0.58466
# 1    C10_2  149.80151 -35.40625    0.11424  0.02920  126.44411   0.50300
# 2    C10_3  149.78896 -35.41875    0.11300  0.03356  188.61237   0.50319
# 3    C10_4  145.56676 -38.22708    0.00201  0.02290  147.48467   0.56545
# 4    C10_5  117.61153 -33.68125    0.05221  0.03066  130.75828   0.88611
# 1   -0.86429   0.30330    -0.80444     0.59404      C     Cf    Cfb
# 2   -0.86418   0.30323     0.14975     0.98872      C     Cf    Cfb
# 3   -0.82479   0.28763    -0.53753     0.84325      C     Cf    Cfb
# 4   -0.46347   0.31288    -0.75747     0.65287      C     Cs    Csb
# 5   -0.85768   0.30351    -0.00973     0.99995      C     Cf    Cfb
# 6   -0.84326   0.26196    -0.88216     0.47096      C     Cf    Cfb
# 7   -0.82344   0.28839    -0.78499     0.61951      C     Cf    Cfb
# 8   -0.52343   0.35464    -0.43352     0.90114      B     BW    BWh
# 9   -0.85891   0.30402    -0.05217     0.99864      C     Cf    Cfb
# 10  -0.86958   0.30406    -0.51767     0.85558      C     Cf    Cfb
# 11  -0.85871   0.30385    -0.41689     0.90896      C     Cf    Cfb
# 12  -0.57527   0.40538     0.14663     0.98919      A     Aw    Aw
# 13  -0.77959   0.30422    -0.13745     0.99051      B     BS    BSk
# 14  -0.77948   0.30422    -0.55966     0.82872      B     BS    BSk
# 15  -0.61887   0.41341    -0.66632     0.74566      B     BS    BSh
# 16  -0.57733   0.40520    -0.34838     0.93735      B     BS    BSh
# 17  -0.57890   0.40483     0.47163     0.88179      B     BS    BSh
# 18  -0.44442   0.30990    -0.43053     0.90258      C     Cs    Csb
# 19  -0.85672   0.30323    -0.99353     0.11358      C     Cf    Cfb
# 20  -0.85738   0.30441    -0.95610     0.29304      C     Cf    Cfb
# 21  -0.84944   0.30196    -0.04286     0.99908      C     Cf    Cfb
# 22  -0.87134   0.31302    -0.82676     0.56255      C     Cf    Cfa
# 23  -0.87136   0.31300    -0.42457     0.90540      C     Cf    Cfa
# 24  -0.87156   0.31328    -0.78419     0.62053      C     Cf    Cfa
# 25  -0.83497   0.29927    -0.26941     0.96302      C     Cs    Csa
# 26  -0.83531   0.29851    -0.08692     0.99622      C     Cs    Csb
# 27  -0.87226   0.31325    -0.38931     0.92111      C     Cf    Cfa
# 28  -0.85551   0.29082     0.08411     0.99646      C     Cf    Cfb
# 29  -0.85817   0.29128    -0.66705     0.74501      C     Cf    Cfb
# 30  -0.85634   0.29108    -0.26298     0.96480      C     Cf    Cfb
# 31  -0.82148   0.29179    -0.81808     0.57511      C     Cf    Cfb
# 32  -0.86805   0.31284     0.40425     0.91465      C     Cf    Cfb
# 33  -0.84184   0.29922     0.10230     0.99475      C     Cs    Csb
# 34  -0.87007   0.31075     0.13836     0.99038      C     Cf    Cfb
# 35  -0.87210   0.31594     0.14001     0.99015      C     Cf    Cfa
# 36  -0.84944   0.30191    -0.65057     0.75945      C     Cf    Cfb
# 37  -0.86939   0.31253    -0.72202     0.69187      C     Cf    Cfb
# 38  -0.80998   0.29209     0.10073     0.99491      C     Cf    Cfb
# 39  -0.85763   0.30402    -0.12761     0.99182      C     Cf    Cfb
# 40  -0.85552   0.30223    -0.62931     0.77715      C     Cf    Cfb
# 41  -0.85593   0.30219    -0.98912    -0.14709      C     Cf    Cfb

# %% [markdown]
# ### Sample processing
# Create the auxiliary dataset from the samples
#
# ##### Step 1: Merge sites and sample data to add the site longitude and latitude to the samples

# %%
samples = dem_norm[["Site", "Longitude", "Latitude"]].merge(
    LFMC_data[["ID", "Site", "Sampling date", "Sampling year", "Land Cover", "LFMC value"]])
samples
# Out:
#       Site  Longitude  Latitude        ID Sampling date  Sampling year  \
# 0    C10_1  144.22103 -37.63542   C10_1_1    2008-10-20           2008
# 1    C10_1  144.22103 -37.63542   C10_1_2    2008-11-10           2008
# 2    C10_1  144.22103 -37.63542   C10_1_3    2008-12-01           2008
# 3    C10_1  144.22103 -37.63542   C10_1_4    2009-01-19           2009
# 4    C10_2  149.80151 -35.40625   C10_2_1    2006-01-05           2006
# ..     ...        ...       ...       ...           ...            ...
# 668  C18_3  148.86310 -35.60625  C18_3_32    2016-09-02           2016
# 669  C18_3  148.86310 -35.60625  C18_3_33    2016-09-02           2016
# 670  C18_3  148.86310 -35.60625  C18_3_34    2016-11-01           2016
# 671  C18_3  148.86310 -35.60625  C18_3_35    2016-11-01           2016
# 672  C18_3  148.86310 -35.60625  C18_3_36    2016-11-01           2016
#
#                                             Land Cover  LFMC value
# 0                                            Grassland  260.570000
# 1                                            Grassland  162.340000
# 2                                            Grassland  132.660000
# 3                                            Grassland   95.810000
# 4    Mosaic cropland (>50%) / natural vegetation (t...   63.000000
# ..                                                 ...         ...
# 668  Tree cover, broadleaved, evergreen, closed to ...  176.192379
# 669  Tree cover, broadleaved, evergreen, closed to ...  148.072003
# 670  Tree cover, broadleaved, evergreen, closed to ...   97.565123
# 671  Tree cover, broadleaved, evergreen, closed to ...  166.557840
# 672  Tree cover, broadleaved, evergreen, closed to ...  149.553088
#
# [673 rows x 8 columns]

# %% [markdown]
# ##### Step 2: Merge samples for same latitude/longitude/date

# %%
# Generate a common site id for each site with the same latitude and longitude
merge_columns = ["Latitude", "Longitude"]
sites_temp = dem_norm[merge_columns + ["Site"]].groupby(merge_columns, as_index=False).min()
# Merge samples for same year and location
samples = samples.merge(sites_temp, on=merge_columns, suffixes=("_x", None))
groupby_cols = ["Latitude", "Longitude", "Sampling date"]
data_cols = {"ID": "min",                                    # Unique sample ID is the first ID of the merged samples
             "Sampling year": "min",                         # They should all be the same, but need to select one
             "Land Cover": lambda x: pd.Series.mode(x)[0],   # Most common land cover value
             "LFMC value": "mean",                           # mean LFMC value
             "Site": "min"}                                  # Site id from sites_temp
samples = samples[groupby_cols + list(data_cols.keys())].groupby(groupby_cols, as_index=False).\
              agg(data_cols).round({"LFMC value": FLOAT_PRE})
samples
# Out:
#      Latitude  Longitude Sampling date         ID  Sampling year  \
# 0   -42.84792  147.48628    2006-03-01    C10_7_1           2006
# 1   -38.22708  145.56676    2008-01-15    C10_4_1           2008
# 2   -38.22708  145.56676    2008-01-22    C10_4_2           2008
# 3   -38.22708  145.56676    2008-01-29    C10_4_3           2008
# 4   -38.22708  145.56676    2008-02-05    C10_4_4           2008
# ..        ...        ...           ...        ...            ...
# 385 -15.58542  128.23378    2006-09-05  C10_16_10           2006
# 386 -15.58542  128.23378    2006-12-19  C10_16_11           2006
# 387 -15.58542  128.23378    2007-04-26  C10_16_12           2007
# 388 -15.58542  128.23378    2007-05-21  C10_16_13           2007
# 389 -15.58542  128.23378    2007-07-09  C10_16_14           2007
#
#                                             Land Cover  LFMC value    Site
# 0                                  Shrubland deciduous    35.04517   C10_7
# 1                                            Grassland    58.84256   C10_4
# 2                                            Grassland    49.42399   C10_4
# 3                                            Grassland    49.74228   C10_4
# 4                                            Grassland    45.46927   C10_4
# ..                                                 ...         ...     ...
# 385  Mosaic tree and shrub (>50%) / herbaceous cove...    28.39000  C10_16
# 386  Mosaic tree and shrub (>50%) / herbaceous cove...   161.20000  C10_16
# 387  Mosaic tree and shrub (>50%) / herbaceous cove...    74.10000  C10_16
# 388  Mosaic tree and shrub (>50%) / herbaceous cove...    56.50000  C10_16
# 389  Mosaic tree and shrub (>50%) / herbaceous cove...    60.12000  C10_16
#
# [390 rows x 8 columns]

# %% [markdown]
# ##### Step 3: Add the normalised auxiliary variables (day-of-year, location and DEM) to the samples

# %%
aux_df = samples[["ID", "Latitude", "Longitude", "Sampling date", "Sampling year", "Land Cover", "LFMC value", "Site"]
                ].merge(days_df, left_on="Sampling date", right_on = "Date").drop(columns="Date").\
                merge(dem_norm.drop(columns=["Longitude", "Latitude"]), on="Site").sort_values("ID")
aux_df = aux_df[['ID', 'Latitude', 'Longitude', 'Sampling date', 'Sampling year', 'Land Cover', 'LFMC value', 'Site',
                 'Czone1', 'Czone2', 'Czone3',
                 'Day_sin', 'Day_cos',
                 'Long_sin', 'Long_cos', 'Lat_norm', 'Elevation', 'Slope', 'Aspect_sin', 'Aspect_cos']]
aux_df.to_csv(SAMPLES_OUTPUT, index=False)
aux_df
# Out:
#             ID  Latitude  Longitude Sampling date  Sampling year  \
# 80    C10_10_1 -35.27708  149.19474    2005-08-16           2005
# 88   C10_10_10 -35.27708  149.19474    2006-12-13           2006
# 89   C10_10_11 -35.27708  149.19474    2007-01-25           2007
# 53   C10_10_12 -35.27708  149.19474    2007-10-17           2007
# 54   C10_10_13 -35.27708  149.19474    2007-10-29           2007
# ..         ...       ...        ...           ...            ...
# 187   C18_3_28 -35.60625  148.86310    2016-02-16           2016
# 188   C18_3_31 -35.60625  148.86310    2016-09-02           2016
# 189   C18_3_34 -35.60625  148.86310    2016-11-01           2016
# 179    C18_3_4 -35.60625  148.86310    2015-10-12           2015
# 180    C18_3_7 -35.60625  148.86310    2015-10-27           2015
#
#                                             Land Cover  LFMC value    Site  \
# 80   Mosaic cropland (>50%) / natural vegetation (t...    48.00000  C10_10
# 88   Mosaic cropland (>50%) / natural vegetation (t...    10.16000  C10_10
# 89   Mosaic cropland (>50%) / natural vegetation (t...     5.90000  C10_10
# 53   Mosaic cropland (>50%) / natural vegetation (t...    91.81000  C10_10
# 54   Mosaic cropland (>50%) / natural vegetation (t...   128.80000  C10_10
# ..                                                 ...         ...     ...
# 187  Tree cover, broadleaved, evergreen, closed to ...   136.38340   C18_3
# 188  Tree cover, broadleaved, evergreen, closed to ...   145.09527   C18_3
# 189  Tree cover, broadleaved, evergreen, closed to ...   137.89202   C18_3
# 179  Tree cover, broadleaved, evergreen, closed to ...   116.44435   C18_3
# 180  Tree cover, broadleaved, evergreen, closed to ...   114.04380   C18_3
#
#     Czone1 Czone2 Czone3  Day_sin  Day_cos  Long_sin  Long_cos  Lat_norm  \
# 80       C     Cf    Cfb  0.69328  0.72067   0.51212  -0.85891   0.30402
# 88       C     Cf    Cfb  0.32127 -0.94699   0.51212  -0.85891   0.30402
# 89       C     Cf    Cfb -0.40149 -0.91586   0.51212  -0.85891   0.30402
# 53       C     Cf    Cfb  0.96574 -0.25951   0.51212  -0.85891   0.30402
# 54       C     Cf    Cfb  0.89198 -0.45207   0.51212  -0.85891   0.30402
# ..     ...    ...    ...      ...      ...       ...       ...       ...
# 187      C     Cf    Cfb -0.71166 -0.70253   0.51708  -0.85593   0.30219
# 188      C     Cf    Cfb  0.88001  0.47495   0.51708  -0.85593   0.30219
# 189      C     Cf    Cfb  0.85876 -0.51237   0.51708  -0.85593   0.30219
# 179      C     Cf    Cfb  0.98447 -0.17553   0.51708  -0.85593   0.30219
# 180      C     Cf    Cfb  0.90701 -0.42110   0.51708  -0.85593   0.30219
#
#      Elevation    Slope  Aspect_sin  Aspect_cos
# 80     0.09635  0.02366    -0.05217     0.99864
# 88     0.09635  0.02366    -0.05217     0.99864
# 89     0.09635  0.02366    -0.05217     0.99864
# 53     0.09635  0.02366    -0.05217     0.99864
# 54     0.09635  0.02366    -0.05217     0.99864
# ..         ...      ...         ...         ...
# 187    0.21129  0.16830    -0.98912    -0.14709
# 188    0.21129  0.16830    -0.98912    -0.14709
# 189    0.21129  0.16830    -0.98912    -0.14709
# 179    0.21129  0.16830    -0.98912    -0.14709
# 180    0.21129  0.16830    -0.98912    -0.14709
#
# [390 rows x 20 columns]

# %%
land_cover = sorted(aux_df['Land Cover'].unique())
land_cover
# Out:
# ['Cropland, rainfed',
#  'Grassland',
#  'Herbaceous cover',
#  'Mosaic cropland (>50%) / natural vegetation (tree, shrub, herbaceous cover) (<50%)',
#  'Mosaic natural vegetation (tree, shrub, herbaceous cover) (>50%) / cropland (<50%) ',
#  'Mosaic tree and shrub (>50%) / herbaceous cover (<50%)',
#  'Shrubland deciduous',
#  'Tree cover, broadleaved, evergreen, closed to open (>15%)',
#  'Urban areas']

# %%
landcover_groups = {
    'Agriculture': [0, 3, 4],
    'Forest': [5, 7],
    'Grassland': [1, 2],
    'Shrubland': [6],
    'Other': [8],
}
lc_labels = list(landcover_groups.keys())

lc_summary = aux_df.groupby(['Land Cover', 'Site'], as_index=False
                           ).size().groupby(['Land Cover']).agg({'size': 'sum', "Site": "count"})
lc_summary['landcover_group'] = ''
for group, classes in landcover_groups.items():
    lc = [land_cover[c] for c in classes]
    lc_summary.loc[lc, 'landcover_group'] = group
lc_summary = lc_summary.reset_index()
lc_summary.columns = ['Land Cover', '#Samples', '#Sites', 'LC Category']

# %%
cols = list(aux_df.columns)
cols.insert(5, 'LC Category')
aux_df = aux_df.merge(lc_summary[['LC Category', 'Land Cover']])[cols]
aux_df
# Out:
#             ID  Latitude  Longitude Sampling date  Sampling year  LC Category  \
# 0     C10_10_1 -35.27708  149.19474    2005-08-16           2005  Agriculture
# 1    C10_10_10 -35.27708  149.19474    2006-12-13           2006  Agriculture
# 2    C10_10_11 -35.27708  149.19474    2007-01-25           2007  Agriculture
# 3    C10_10_12 -35.27708  149.19474    2007-10-17           2007  Agriculture
# 4    C10_10_13 -35.27708  149.19474    2007-10-29           2007  Agriculture
# ..         ...       ...        ...           ...            ...          ...
# 385   C10_20_7 -35.41875  148.95045    2007-03-21           2007  Agriculture
# 386   C10_20_8 -35.41875  148.95045    2007-04-16           2007  Agriculture
# 387   C10_20_9 -35.41875  148.95045    2007-05-02           2007  Agriculture
# 388   C10_21_1 -35.20625  149.02369    2005-08-30           2005        Other
# 389   C10_21_2 -35.20625  149.02369    2005-09-01           2005        Other
#
#                                             Land Cover  LFMC value    Site  \
# 0    Mosaic cropland (>50%) / natural vegetation (t...    48.00000  C10_10
# 1    Mosaic cropland (>50%) / natural vegetation (t...    10.16000  C10_10
# 2    Mosaic cropland (>50%) / natural vegetation (t...     5.90000  C10_10
# 3    Mosaic cropland (>50%) / natural vegetation (t...    91.81000  C10_10
# 4    Mosaic cropland (>50%) / natural vegetation (t...   128.80000  C10_10
# ..                                                 ...         ...     ...
# 385                                  Cropland, rainfed   336.00000  C10_20
# 386                                  Cropland, rainfed   108.60000  C10_20
# 387                                  Cropland, rainfed   145.80000  C10_20
# 388                                        Urban areas    46.00000  C10_21
# 389                                        Urban areas    49.33333  C10_21
#
#     Czone1  ... Czone3  Day_sin  Day_cos  Long_sin  Long_cos  Lat_norm  \
# 0        C  ...    Cfb  0.69328  0.72067   0.51212  -0.85891   0.30402
# 1        C  ...    Cfb  0.32127 -0.94699   0.51212  -0.85891   0.30402
# 2        C  ...    Cfb -0.40149 -0.91586   0.51212  -0.85891   0.30402
# 3        C  ...    Cfb  0.96574 -0.25951   0.51212  -0.85891   0.30402
# 4        C  ...    Cfb  0.89198 -0.45207   0.51212  -0.85891   0.30402
# ..     ...  ...    ...      ...      ...       ...       ...       ...
# 385      C  ...    Cfb -0.97785 -0.20931   0.51578  -0.85672   0.30323
# 386      C  ...    Cfb -0.97212  0.23449   0.51578  -0.85672   0.30323
# 387      C  ...    Cfb -0.87171  0.49003   0.51578  -0.85672   0.30323
# 388      C  ...    Cfb  0.84525  0.53437   0.51468  -0.85738   0.30441
# 389      C  ...    Cfb  0.86314  0.50496   0.51468  -0.85738   0.30441
#
#      Elevation    Slope  Aspect_sin  Aspect_cos
# 0      0.09635  0.02366    -0.05217     0.99864
# 1      0.09635  0.02366    -0.05217     0.99864
# 2      0.09635  0.02366    -0.05217     0.99864
# 3      0.09635  0.02366    -0.05217     0.99864
# 4      0.09635  0.02366    -0.05217     0.99864
# ..         ...      ...         ...         ...
# 385    0.10795  0.04367    -0.99353     0.11358
# 386    0.10795  0.04367    -0.99353     0.11358
# 387    0.10795  0.04367    -0.99353     0.11358
# 388    0.09647  0.03897    -0.95610     0.29304
# 389    0.09647  0.03897    -0.95610     0.29304
#
# [390 rows x 21 columns]

# %%
aux_df.to_csv(SAMPLES_OUTPUT, index=False)

# %%
aux_df.groupby(['Sampling year']).size()
# Out:
# Sampling year
# 2005    11
# 2006    57
# 2007    48
# 2008    64
# 2009    23
# 2012     3
# 2013    56
# 2014    67
# 2015    41
# 2016    20
# dtype: int64

# %%
aux_df.groupby(['Czone3']).size()
# Out:
# Czone3
# Aw       9
# BSh     27
# BSk     18
# BWh     11
# Cfa     43
# Cfb    250
# Csa      9
# Csb     23
# dtype: int64

# %%
aux_df.groupby(['Site', 'Sampling year']).size().unstack()
# Out:
# Sampling year  2005  2006  2007  2008  2009  2012  2013  2014  2015  2016
# Site
# C10_1           NaN   NaN   NaN   3.0   1.0   NaN   NaN   NaN   NaN   NaN
# C10_10          2.0   8.0   6.0  13.0  11.0   NaN   NaN   NaN   NaN   NaN
# C10_11          1.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# C10_12          5.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# C10_13          NaN   5.0   4.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# C10_14          NaN   NaN   NaN   9.0   NaN   NaN   NaN   NaN   NaN   NaN
# C10_15          NaN   NaN   NaN   9.0   NaN   NaN   NaN   NaN   NaN   NaN
# C10_16          NaN  11.0   3.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# C10_17          NaN   4.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# C10_18          NaN   5.0   4.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# C10_19          NaN   3.0   NaN   4.0   NaN   NaN   NaN   NaN   NaN   NaN
# C10_2           NaN   2.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# C10_20          NaN   6.0   9.0  12.0  11.0   NaN   NaN   NaN   NaN   NaN
# C10_21          2.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# C10_3           NaN   6.0  15.0   2.0   NaN   NaN   NaN   NaN   NaN   NaN
# C10_4           NaN   NaN   NaN   6.0   NaN   NaN   NaN   NaN   NaN   NaN
# C10_5           NaN   1.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# C10_6           1.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# C10_7           NaN   1.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# C10_8           NaN   NaN   1.0   6.0   NaN   NaN   NaN   NaN   NaN   NaN
# C10_9           NaN   5.0   6.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# C11_1           NaN   NaN   NaN   NaN   NaN   NaN   NaN   3.0   NaN   NaN
# C11_10          NaN   NaN   NaN   NaN   NaN   NaN   2.0   1.0   NaN   NaN
# C11_11          NaN   NaN   NaN   NaN   NaN   NaN   2.0   2.0   NaN   NaN
# C11_12          NaN   NaN   NaN   NaN   NaN   NaN   NaN   5.0   NaN   NaN
# C11_13          NaN   NaN   NaN   NaN   NaN   NaN   3.0   3.0   NaN   NaN
# C11_14          NaN   NaN   NaN   NaN   NaN   NaN   NaN   5.0   NaN   NaN
# C11_15          NaN   NaN   NaN   NaN   NaN   NaN   NaN   5.0   NaN   NaN
# C11_16          NaN   NaN   NaN   NaN   NaN   NaN   7.0   3.0   NaN   NaN
# C11_17          NaN   NaN   NaN   NaN   NaN   NaN   NaN   4.0   NaN   NaN
# C11_18          NaN   NaN   NaN   NaN   NaN   NaN   5.0   9.0   NaN   NaN
# C11_2           NaN   NaN   NaN   NaN   NaN   NaN   5.0   NaN   NaN   NaN
# C11_3           NaN   NaN   NaN   NaN   NaN   NaN   7.0   NaN   NaN   NaN
# C11_4           NaN   NaN   NaN   NaN   NaN   NaN   NaN   5.0   NaN   NaN
# C11_5           NaN   NaN   NaN   NaN   NaN   NaN   3.0   6.0   NaN   NaN
# C11_6           NaN   NaN   NaN   NaN   NaN   NaN   3.0   6.0   NaN   NaN
# C11_7           NaN   NaN   NaN   NaN   NaN   3.0  15.0   3.0   NaN   NaN
# C11_8           NaN   NaN   NaN   NaN   NaN   NaN   2.0   1.0   NaN   NaN
# C11_9           NaN   NaN   NaN   NaN   NaN   NaN   2.0   1.0   NaN   NaN
# C18_1           NaN   NaN   NaN   NaN   NaN   NaN   NaN   5.0  24.0  12.0
# C18_2           NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   9.0   4.0
# C18_3           NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   8.0   4.0
